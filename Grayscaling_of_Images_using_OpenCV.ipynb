# %% [markdown]
# <a href="https://colab.research.google.com/github/vinayparjapati5/Grayscaling-of-Images-using-OpenCV/blob/main/Grayscaling_of_Images_using_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# ## **Mini Project : Convert 100 images to Gray Scale (b/w) using OpenCV**
# ---

# %% [markdown]
# ---
# ### 1. Download 100 Images
# ---

# %%
# !pip install bing-image-downloader &> /dev/null  # install
print(" Bing Image downloader installed successfully")

from bing_image_downloader import downloader   #import

downloader.download("Bird", limit=100)
# Out:
#  Bing Image downloader installed successfully
# [%] Downloading Images to /content/dataset/Bird
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.freshboo.com/wp-content/uploads/2014/11/eastern-bluebird-wallpaper.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://i.stack.imgur.com/e3Rua.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://www.birdsandblooms.com/wp-content/uploads/2016/05/bluebird.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.borealbirds.org/sites/default/files/bird_images/eastern-kingbird.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://nzbirdsonline.org.nz/sites/all/files/1200543tui.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://1.bp.blogspot.com/-USsF2WR287s/TqvSzg0HTaI/AAAAAAAACQA/scBUg6SlLOc/s1600/cendrawasih-flying.jpg
# [%] File Downloaded !
#
# ...

# %% [markdown]
# ---
# ### 2. Convert the 100 images to grayscale
# ---

# %%
import cv2
import os

# Define the directory path where the images are located
directory = "/content/dataset/Bird"

# Loop through all the files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Read the image
        img_path = os.path.join(directory, filename)
        img = cv2.imread(img_path)

        # Convert the image to grayscale
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Save the grayscale image with a new filename
        new_filename = "gray_" + filename
        new_img_path = os.path.join(directory, new_filename)
        cv2.imwrite(new_img_path, gray_img)

        print(f"Converted {filename} to grayscale: {new_filename}")
# Out:
# Converted Image_29.jpg to grayscale: gray_Image_29.jpg
# Converted Image_89.jpg to grayscale: gray_Image_89.jpg
# Converted Image_7.jpg to grayscale: gray_Image_7.jpg
# Converted Image_63.jpg to grayscale: gray_Image_63.jpg
# Converted Image_66.jpg to grayscale: gray_Image_66.jpg
# Converted Image_36.jpg to grayscale: gray_Image_36.jpg
# Converted Image_47.jpg to grayscale: gray_Image_47.jpg
# Converted Image_88.jpg to grayscale: gray_Image_88.jpg
# Converted Image_27.jpg to grayscale: gray_Image_27.jpg
# Converted Image_75.jpg to grayscale: gray_Image_75.jpg
# Converted Image_15.jpg to grayscale: gray_Image_15.jpg
# Converted Image_97.jpg to grayscale: gray_Image_97.jpg
# Converted Image_83.jpg to grayscale: gray_Image_83.jpg
# Converted Image_12.jpg to grayscale: gray_Image_12.jpg
# Converted Image_71.jpg to grayscale: gray_Image_71.jpg
# Converted Image_26.jpg to grayscale: gray_Image_26.jpg
# Converted Image_10.jpg to grayscale: gray_Image_10.jpg
# ...

# %% [markdown]
# ---
# ### 3. Download file in your Google drive
# ---

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile

# Path to the folder you want to download
folder_path = '/content/dataset/Bird'

# Name for the output zip file
zip_filename = '/content/drive/MyDrive/Bird_input_output(grayscale).zip'

# Create a zip file of the folder
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            zipf.write(file_path, arcname=os.path.relpath(file_path, folder_path))
